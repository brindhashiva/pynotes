# %%
name = "Brindha"
age = 20
print(name)
print(age)
# Out:
# Brindha
# 20

# %%
num = int(input("Enter number: "))
print("You entered:", num)
# Out:
# Enter number:  7
# You entered: 7

# %%
a = 10
b = 3
print("Add:", a + b)
print("Sub:", a - b)
print("Mul:", a * b)
print("Div:", a / b)
# Out:
# Add: 13
# Sub: 7
# Mul: 30
# Div: 3.3333333333333335
