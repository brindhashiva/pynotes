# %%
student = {"name": "Brindha", "age": 20}
print(student)
# Out:
# {'name': 'Brindha', 'age': 20}

# %%
student = {"name": "Brindha", "age": 20}
print(student["name"])
# Out:
# Brindha

# %%
student = {"name": "Brindha"}
student["age"] = 20
print(student)
# Out:
# {'name': 'Brindha', 'age': 20}
