# %%
text = "python"
print(len(text))
# Out:
# 6

# %%
text = "hello world"
print(text.split())
# Out:
# ['hello', 'world']

# %%
words = ["python", "is", "easy"]
print(" ".join(words))
# Out:
# python is easy
