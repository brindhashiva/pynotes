# %%
a = 10
b = "5"
try:
    print(a + b)
except TypeError:
    print("Type error occurred")
# Out:
# Type error occurred

# %%
num = int("10")
print(num)
# Out:
# 10

# %%
x = 10
print("Memory id:", id(x))
# Out:
# Memory id: 140723596978904
