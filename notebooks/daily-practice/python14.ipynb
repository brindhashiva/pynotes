# %%
def show():
    """This function prints a message"""
    print("Docstring example")

show()
# Out:
# Docstring example

# %%
def helper(a, b):
    return a * b

print(helper(2, 3))
# Out:
# 6

# %%
def display(name, age):
    print(f"{name} - {age}")

display("Brindha", 20)
# Out:
# Brindha - 20
