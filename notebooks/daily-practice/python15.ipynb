# %%
a = [1, 2, 3]
b = a
b.append(4)
print("List:", a)
# Out:
# List: [1, 2, 3, 4]

# %%
a = (1, 2, 3)
# a[0] = 5  # error (immutable)
print(a)
# Out:
# (1, 2, 3)

# %%
a = {"x": 1}
b = a
b["y"] = 2
print(a)
# Out:
# {'x': 1, 'y': 2}
