# %%
nums = [3, 6, 9, 12]
for i in range(len(nums)):
    print(i, nums[i])
# Out:
# 0 3
# 1 6
# 2 9
# 3 12

# %%
nums = [1, 2, 3]
squares = [x * x for x in nums]
print(squares)
# Out:
# [1, 4, 9]

# %%
nums = [1, 2, 3, 4, 5]
odd = [x for x in nums if x % 2 != 0]
print(odd)
# Out:
# [1, 3, 5]
