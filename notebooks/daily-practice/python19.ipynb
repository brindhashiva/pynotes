# %%
text = "python"
print(text.endswith("n"))
# Out:
# True

# %%
nums = [10, 20, 30]
nums.insert(1, 15)
print(nums)
# Out:
# [10, 15, 20, 30]

# %%
nums = [10, 20, 30]
nums.remove(20)
print(nums)
# Out:
# [10, 30]
