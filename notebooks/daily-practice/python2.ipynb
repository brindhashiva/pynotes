# %%
num = 5
print("Type:", type(num))
num = float(num)
print("Converted:", num)
# Out:
# Type: <class 'int'>
# Converted: 5.0

# %%
name = "Brindha"
print(f"My name is {name}")
# Out:
# My name is Brindha

# %%
a = 10
b = 20
print("Before swap:", a, b)
a, b = b, a
print("After swap:", a, b)
# Out:
# Before swap: 10 20
# After swap: 20 10
