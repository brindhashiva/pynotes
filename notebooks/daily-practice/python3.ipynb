# %%
num = int(input("Enter number: "))
if num > 0:
    print("Positive")
else:
    print("Negative or zero")
# Out:
# Enter number:  7
# Positive

# %%
marks = 75
if marks >= 90:
    print("A")
elif marks >= 60:
    print("B")
else:
    print("C")
# Out:
# B

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
