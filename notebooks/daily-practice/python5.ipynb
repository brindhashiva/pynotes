# %%
def greet():
    print("Hello")

greet()
# Out:
# Hello

# %%
def greet(name):
    print("Hello", name)

greet("Brindha")
# Out:
# Hello Brindha

# %%
def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# 8
