# %%
def details(name, age):
    print(f"{name} is {age} years old")

details("Brindha", 20)
# Out:
# Brindha is 20 years old

# %%
def square(x):
    return x * x

print(square(4))
# Out:
# 16

# %%
def info(name="Student"):
    print("Hello", name)

info()
info("Brindha")
# Out:
# Hello Student
# Hello Brindha
