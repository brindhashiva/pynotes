# %%
nums = [10, 20, 30]
for n in nums:
    print(n)
# Out:
# 10
# 20
# 30

# %%
nums = [1, 2, 3, 4]
print(nums[1:3])
# Out:
# [2, 3]

# %%
nums = [5, 10, 15]
print("Max:", max(nums))
print("Min:", min(nums))
# Out:
# Max: 15
# Min: 5
